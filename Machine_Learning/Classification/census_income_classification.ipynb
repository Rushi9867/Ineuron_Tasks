# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
df1 = pd.read_csv('census_income_data.csv',names=['age','workclass','fnlwgt','education','education_num',
'marital_status','occupation','relationship','race','sex','capitalgain','capital_loss','hours_per_week','native_country','income'])

# %%
df2 = pd.read_csv('census_income_test.csv',names=['age','workclass','fnlwgt','education','education_num',
'marital_status','occupation','relationship','race','sex','capitalgain','capital_loss','hours_per_week','native_country','income'])

# %%
df = df1.append(df2, sort=False)

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.nunique()
# Out:
# age                  74
# workclass             9
# fnlwgt            28523
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capitalgain         123
# capital_loss         99
# hours_per_week       96
# native_country       42
# income                4
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capitalgain        int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capitalgain       0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.describe(include='all').T
# Out:
#                   count unique                  top   freq           mean  \
# age             48842.0    NaN                  NaN    NaN      38.643585
# workclass         48842      9              Private  33906            NaN
# fnlwgt          48842.0    NaN                  NaN    NaN  189664.134597
# education         48842     16              HS-grad  15784            NaN
# education_num   48842.0    NaN                  NaN    NaN      10.078089
# marital_status    48842      7   Married-civ-spouse  22379            NaN
# occupation        48842     15       Prof-specialty   6172            NaN
# relationship      48842      6              Husband  19716            NaN
# race              48842      5                White  41762            NaN
# sex               48842      2                 Male  32650            NaN
# capitalgain     48842.0    NaN                  NaN    NaN    1079.067626
# capital_loss    48842.0    NaN                  NaN    NaN      87.502314
# ...

# %%
df.drop_duplicates()
# Out:
#        age          workclass  fnlwgt   education  education_num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 16276   39            Private  215419   Bachelors             13
# 16277   64                  ?  321403     HS-grad              9
# 16278   38            Private  374983   Bachelors             13
# 16279   44            Private   83891   Bachelors             13
# 16280   35       Self-emp-inc  182148   Bachelors             13
#
#             marital_status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# ...

# %%
df['income'].unique()
# Out:
# array([' <=50K', ' >50K', ' <=50K.', ' >50K.'], dtype=object)

# %%
df['income'].replace({' <=50K':0,' <=50K.':0,' >50K':1,' >50K.':1},inplace=True)

# %%
num_feat = [num for num in df.columns if df[num].dtypes !='O']
print('We have {} numerical features are {}'.format(len(num_feat),num_feat))
# Out:
# We have 7 numerical features are ['age', 'fnlwgt', 'education_num', 'capitalgain', 'capital_loss', 'hours_per_week', 'income']

# %%
cat_feat = [cat for cat in df.columns if df[cat].dtypes == 'O']
print('We have {} categorical features are {}'.format(len(cat_feat),cat_feat))
# Out:
# We have 8 categorical features are ['workclass', 'education', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'native_country']

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capitalgain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
df = df.drop_duplicates()

# %%
for i in df.columns:
    print('{}:{}'.format(i,df[i].unique()))
    print()
# Out:
# age:[39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87 89]
#
# workclass:[' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#
# fnlwgt:[ 77516  83311 215646 ... 173449  89686 350977]
#
# education:[' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# education_num:[13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# marital_status:[' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation:[' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capitalgain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
for i in['workclass','occupation','native_country']:
    print('Mode of {} is {}'.format(i,df[i].mode()[0]))
# Out:
# Mode of workclass is  Private
# Mode of occupation is  Prof-specialty
# Mode of native_country is  United-States

# %%
for i in df.columns:
    df[i].replace(' ?',df[i].mode()[0],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48790 non-null  int64
#  1   workclass       48790 non-null  object
#  2   fnlwgt          48790 non-null  int64
#  3   education       48790 non-null  object
#  4   education_num   48790 non-null  int64
#  5   marital_status  48790 non-null  object
#  6   occupation      48790 non-null  object
#  7   relationship    48790 non-null  object
#  8   race            48790 non-null  object
#  9   sex             48790 non-null  object
#  10  capitalgain     48790 non-null  int64
#  11  capital_loss    48790 non-null  int64
#  12  hours_per_week  48790 non-null  int64
#  13  native_country  48790 non-null  object
#  14  income          48790 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 6.0+ MB

# %%
df.skew()
# Out:
# age                0.556582
# fnlwgt             1.439698
# education_num     -0.314229
# capitalgain       11.888265
# capital_loss       4.567037
# hours_per_week     0.239652
# income             1.221366
# dtype: float64

# %%
df.kurt()
# Out:
# age                -0.186851
# fnlwgt              6.061237
# education_num       0.621267
# capitalgain       152.526968
# capital_loss       19.987928
# hours_per_week      2.950820
# income             -0.508285
# dtype: float64

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in num_feat:
    if plotnumber<=7:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot: >

# %%
df[['education_num', 'education']].value_counts().reset_index().sort_values(by='education_num')
# Out:
#     education_num      education      0
# 15              1      Preschool     81
# 14              2        1st-4th    245
# 13              3        5th-6th    507
# 8               4        7th-8th    954
# 10              5            9th    756
# 7               6           10th   1389
# 5               7           11th   1812
# 11              8           12th    655
# 0               9        HS-grad  15770
# 1              10   Some-college  10863
# 4              11      Assoc-voc   2060
# 6              12     Assoc-acdm   1601
# 2              13      Bachelors   8013
# 3              14        Masters   2656
# 9              15    Prof-school    834
# 12             16      Doctorate    594

# %%
df[['age', 'sex','marital_status','relationship']].value_counts().reset_index().sort_values(by='age')
# Out:
#       age      sex          marital_status     relationship    0
# 45     17     Male           Never-married        Own-child  267
# 431    17     Male           Never-married   Other-relative   17
# 939    17   Female           Never-married        Unmarried    4
# 1699   17     Male      Married-civ-spouse          Husband    1
# 1700   17     Male   Married-spouse-absent   Other-relative    1
# ...   ...      ...                     ...              ...  ...
# 1459   90   Female               Separated    Not-in-family    1
# 1444   90   Female                Divorced    Not-in-family    1
# 937    90   Female           Never-married        Own-child    4
# 1108   90   Female           Never-married    Not-in-family    3
# 1940   90     Male                 Widowed        Unmarried    1
#
# [1941 rows x 5 columns]

# %%
df[['native_country', 'workclass']].value_counts().reset_index().sort_values(by='native_country')
# Out:
#     native_country          workclass   0
# 205       Cambodia        Federal-gov   1
# 169       Cambodia          State-gov   1
# 38        Cambodia            Private  24
# 145       Cambodia   Self-emp-not-inc   2
# 45          Canada   Self-emp-not-inc  19
# ..             ...                ...  ..
# 170        Vietnam       Self-emp-inc   1
# 49      Yugoslavia            Private  17
# 162     Yugoslavia       Self-emp-inc   1
# 164     Yugoslavia          Local-gov   1
# 102     Yugoslavia   Self-emp-not-inc   4
#
# [206 rows x 3 columns]

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capitalgain  capital_loss  hours_per_week  native_country  income
# 0         2174             0              40   United-States       0
# ...

# %%
import missingno as msno

# %%
msno.bar(df, color="blue", sort="ascending", figsize=(10,5), fontsize=12)
# Out:
# <AxesSubplot: >

# %%
df['native_country'].value_counts(normalize=True).head(10)
# Out:
#  United-States    0.915106
#  Mexico           0.019328
#  Philippines      0.006026
#  Germany          0.004222
#  Puerto-Rico      0.003771
#  Canada           0.003730
#  El-Salvador      0.003177
#  India            0.003095
#  Cuba             0.002828
#  England          0.002603
# Name: native_country, dtype: float64

# %%
plt.figure(figsize=(20,25))
for i,col in enumerate(num_feat):
    plt.subplot(5,5,i+1)
    sns.boxplot(x=df[col])

# %%
def getIQR(df,col,condition):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    IQR = q3 - q1 
    lower_fence = q1 - 1.5*IQR 
    upper_fence = q3 + 1.5*IQR
    if condition == 'Drop':
        df.drop(df.loc[df[col]<lower_fence].index,inplace=True)
        df.drop(df.loc[df[col]>upper_fence].index,inplace=True)
    elif condition == 'Fill':
        df[col] = np.where(df[col] < lower_fence, lower_fence, df[col])
        df[col] = np.where(df[col] > upper_fence, upper_fence, df[col])

# %%
list = ['age','fnlwgt','education_num','capitalgain','capital_loss','hours_per_week']

for i in list:
    getIQR(df,i,'Fill')

# %%
plt.figure(figsize=(20,25))
for i,col in enumerate(num_feat):
    plt.subplot(5,5,i+1)
    sns.boxplot(x=df[col])

# %%
#import pymongo 
#client = pymongo.MongoClient("mongodb+srv://Rushi:-----@cluster0.ej1dh6s.mongodb.net/?retryWrites=true&w=majority")
#db = client.test
#db

# %%
#db1 = client['census_income_data']
#coll = db1['census_income_record']
#data_db = df.to_dict("records")
#coll.insert_many(data_db)

# %%
for i in cat_feat:
    df.drop([i],axis=1,inplace=True)

# %%
df = df.copy()

# %%
X = df.drop('income',axis=1)
y = df['income']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_tf = scaler.transform(X_train)
X_train_tf
# Out:
# array([[-0.77429679, -0.27441811, -0.04720421,  0.        ,  0.        ,
#          1.42489425],
#        [-1.06788697, -0.74960974,  1.58174444,  0.        ,  0.        ,
#         -0.1897588 ],
#        [-0.18711641, -0.48350537, -0.45444137,  0.        ,  0.        ,
#         -0.1897588 ],
#        ...,
#        [ 0.9138468 ,  1.46206481, -0.45444137,  0.        ,  0.        ,
#         -0.1897588 ],
#        [-1.50827226,  0.31079956, -1.2689157 ,  0.        ,  0.        ,
#         -1.40074859],
#        [-0.3339115 ,  0.59070178,  0.36003295,  0.        ,  0.        ,
#          1.42489425]])

# %%
X_test_tf = scaler.transform(X_test)
X_test_tf
# Out:
# array([[-0.55410414, -0.78796042,  1.17450728,  0.        ,  0.        ,
#          1.82855752],
#        [ 0.32666642, -0.96245337,  1.17450728,  0.        ,  0.        ,
#         -1.40074859],
#        [ 1.57442473, -1.35662067, -2.2870086 ,  0.        ,  0.        ,
#         -0.1897588 ],
#        ...,
#        [-1.43487471, -1.61782497, -0.04720421,  0.        ,  0.        ,
#         -1.40074859],
#        [ 0.25326888, -0.8769172 , -0.04720421,  0.        ,  0.        ,
#         -0.1897588 ],
#        [ 0.17987133, -0.55121451, -0.45444137,  0.        ,  0.        ,
#          1.82855752]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(X_train_tf,i) for i in range(X_train_tf.shape[1])]
vif["Features"] = X.columns

#let's check the values
vif
# Out:
#         vif        Features
# 0  1.016247             age
# 1  1.007160          fnlwgt
# 2  1.035472   education_num
# 3       NaN     capitalgain
# 4       NaN    capital_loss
# 5  1.042892  hours_per_week

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score,classification_report

# %%
model1 = LogisticRegression()

# %%
model1.fit(X_train_tf,y_train)
# Out:
# LogisticRegression()

# %%
ytest_pred = model1.predict(X_test_tf)

# %%
accuracy_score(y_test,ytest_pred)
# Out:
# 0.7866043613707165

# %%
# Confusion Matrix
conf_mat = confusion_matrix(y_test,ytest_pred)
conf_mat
# Out:
# array([[8599,  613],
#        [1990,  996]], dtype=int64)

# %%
true_positive = conf_mat[0][0]
true_positive
# Out:
# 8599

# %%
false_positive = conf_mat[0][1]
false_positive
# Out:
# 613

# %%
false_negative = conf_mat[1][0]
false_negative
# Out:
# 1990

# %%
true_negative = conf_mat[1][1]
true_negative
# Out:
# 996

# %%
# Breaking down the formula for Accuracy
Accuracy = (true_positive + true_negative) / (true_positive +false_positive + false_negative + true_negative)
Accuracy
# Out:
# 0.7866043613707165

# %%
# Precison
Precision = true_positive/(true_positive+false_positive)
Precision
# Out:
# 0.9334563612679114

# %%
# Recall
Recall = true_positive/(true_positive+false_negative)
Recall
# Out:
# 0.812069128340731

# %%
# F1 Score
F1_Score = 2*(Recall * Precision) / (Recall + Precision)
F1_Score
# Out:
# 0.8685419928286451

# %%
print(classification_report(ytest_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87     10589
#            1       0.33      0.62      0.43      1609
#
#     accuracy                           0.79     12198
#    macro avg       0.63      0.72      0.65     12198
# weighted avg       0.85      0.79      0.81     12198

# %%
# Area Under Curve
auc = roc_auc_score(y_test, ytest_pred)
auc
# Out:
# 0.6335064793613502

# %%
fpr, tpr, thresholds = roc_curve(y_test, ytest_pred)

# %%
import numpy as np 
from sklearn.metrics import accuracy_score
accuracy_ls = []
for thres in thresholds:
    y_pred = np.where(ytest_pred>thres,1,0)
    accuracy_ls.append(accuracy_score(y_test,y_pred,normalize=True))

accuracy_ls = pd.concat([pd.Series(thresholds),pd.Series(accuracy_ls)],axis=1)
accuracy_ls.columns = ['thresholds','accuracy']
accuracy_ls.sort_values(by='accuracy',ascending=False,inplace=True)
accuracy_ls.head()
# Out:
#    thresholds  accuracy
# 2           0  0.786604
# 0           2  0.755206
# 1           1  0.755206

# %%
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
