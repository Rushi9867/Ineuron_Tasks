# %%
import pandas as pd 
import numpy as np
data = pd.read_csv("FitBit data.csv")

# %%
# 1. Read this dataset in pandas , mysql and mongodb 
data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
import mysql.connector as conn
mydb = conn.Connect(host='localhost',user='rushi',passwd='Raud!n$0903')
cur = mydb.cursor()
cur.execute('Drop Database IF EXISTS FITBIT')
cur.execute('Create Database FITBIT')
mydb.is_connected()
# Out:
# True

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://rushi:Raud!n$0903@localhost:3306/FITBIT",echo=False)

# %%
data.to_sql('fitbit_data',con=engine,index=False)

# %%
#engine.execute('Select *from fitbit_data').fetchall()

# %%
data1 = pd.read_sql_table('fitbit_data',"mysql+pymysql://rushi:Raud!n$0903@localhost:3306/FITBIT")
data1.head()
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0      0  1503960366    3/25/2016       11004           7.11             7.11
# 1      1  1503960366    3/26/2016       17609          11.55            11.55
# 2      2  1503960366    3/27/2016       12736           8.53             8.53
# 3      3  1503960366    3/28/2016       13231           8.93             8.93
# 4      4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
# ...

# %%
data['ActivityDate'] = pd.to_datetime(data['ActivityDate']).dt.date 
data['ActivityDate'] = data['ActivityDate'].astype(str)
data.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# 4 .Find out in this data that how many unique id's we have 
a = data['Id'].unique()
a.size
# Out:
# 35

# %%
# 5 . which id is one of the active id that you have in whole dataset 
data[data['TotalSteps'] == data['TotalSteps'].max()]['Id']
# Out:
# 454    8877689391
# Name: Id, dtype: int64

# %%
# 6 . how many of them have not logged there activity find out in terms of number of ids 
b = data[data['LoggedActivitiesDistance'] == 0]["Id"].unique()
b.size
# Out:
# 35

# %%
# 7 . Find out who is the laziest person id that we have in dataset 
data[data['SedentaryMinutes'] == data['SedentaryMinutes'].max()]['Id'].unique()
# Out:
# array([1844505072, 2320127002, 2873212765, 2891001357, 4020332650,
#        4057192912, 4319703577, 4388161847, 4702921684, 6117666160,
#        6290855005, 6391747486, 6775888955, 8253242879], dtype=int64)

# %%
# 8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset 
d = data[data['Calories'] > 2500]['Id'].unique()
d.size
# Out:
# 17

# %%
# 9. how many person are not a regular person with respect to activity try to find out those 
data[data['VeryActiveMinutes']==0]['Id'].unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 6117666160, 6290855005, 6391747486, 6775888955,
#        7086361926, 8053475328, 8253242879, 8378563200, 8583815059,
#        8792009665, 8877689391], dtype=int64)

# %%
# 10 . who is the third most active person in this dataset find out those in pandas and in sql both . 
data[data['TotalSteps'] == data['TotalSteps'].max()]['Id'].
# Out:
#   Input In [14]
#     data[data['TotalSteps'] == data['TotalSteps'].max()]['Id'].
#                                                                ^
# SyntaxError: invalid syntax

# %%
# 11 . who is the 5th most laziest person avilable in dataset find it out

# %%
# 12 . what is a totla acumulative calories burn for a person find out

# %%
data.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
for i in enumerate(data):
    print(i)
# Out:
# (0, 'Id')
# (1, 'ActivityDate')
# (2, 'TotalSteps')
# (3, 'TotalDistance')
# (4, 'TrackerDistance')
# (5, 'LoggedActivitiesDistance')
# (6, 'VeryActiveDistance')
# (7, 'ModeratelyActiveDistance')
# (8, 'LightActiveDistance')
# (9, 'SedentaryActiveDistance')
# (10, 'VeryActiveMinutes')
# (11, 'FairlyActiveMinutes')
# (12, 'LightlyActiveMinutes')
# (13, 'SedentaryMinutes')
# (14, 'Calories')

# %%
cur.execute('Drop TABLE IF EXISTS FITBIT.Fitbit_data')
cur.execute('Create Table FITBIT.Fitbit_data(Id BIGINT(35),ActivityDate Date,TotalSteps INT(25), TotalDistance FLOAT(25,10), TrackerDistance FLOAT(25,10),\
        LoggedActivitiesDistance INT(25), VeryActiveDistance FLOAT(25,10), ModeratelyActiveDistance FLOAT(25,10), LightActiveDistance FLOAT(25,10),\
        SedentaryActiveDistance FLOAT(25,10), VeryActiveMinutes INT(25), FairlyActiveMinutes INT(25),LightlyActiveMinutes INT(25), SedentaryMinutes INT(25),\
        Calories INT(25))')
with open("New_FitBit_Data.csv","r") as data1:
        next(data1)
        data_csv = csv.reader(data1,delimiter='\n')
        for i in data_csv:
            cur.execute("Insert Into FITBIT.Fitbit_data values({data})".format(data=(str(i[0]))))
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Python310\lib\site-packages\mysql\connector\connection_cext.py:535, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     534         query = query.encode('utf-8')
# --> 535     self._cmysql.query(query,
#     536                        raw=raw, buffered=buffered,
#     537                        raw_as_string=raw_as_string,
#     538                        query_attrs=self._query_attrs)
#     539 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Incorrect date value: '-2013' for column 'ActivityDate' at row 1
#
# During handling of the above exception, another exception occurred:
#
# DataError                                 Traceback (most recent call last)
# d:\Python Programs\Data_Science Task\task\Task.ipynb Cell 9 in <module>
# ...

# %%
cur.execute("select *from FITBIT.Fitbit_data")
for i in cur.fetchall():
    print(i)
# Out:
# (1503960366, '0.000059523809523809', 11004, 7.1100001335, 7.1100001335, 0, 2.5699999332, 0.4600000083, 4.0700001717, 0.0, 33, 12, 205, 804, 1819)
# (1503960366, '0.000057234432043650', 17609, 11.5500001907, 11.5500001907, 0, 6.9200000763, 0.7300000191, 3.9100000858, 0.0, 89, 17, 274, 588, 2154)
# (1503960366, '0.000055114638392857', 12736, 8.529999733, 8.529999733, 0, 4.6599998474, 0.1599999964, 3.7100000381, 0.0, 56, 5, 268, 605, 1944)
# (1503960366, '0.000053146258432539', 13231, 8.9300003052, 8.9300003052, 0, 3.1900000572, 0.7900000215, 4.9499998093, 0.0, 39, 20, 224, 1080, 1932)
# (1503960366, '0.000051313628472222', 12041, 7.8499999046, 7.8499999046, 0, 2.1600000858, 1.0900000334, 4.6100001335, 0.0, 28, 28, 243, 763, 1886)
# (1503960366, '0.000049603174603174', 10970, 7.1599998474, 7.1599998474, 0, 2.3599998951, 0.5099999905, 4.2899999619, 0.0, 30, 13, 223, 1174, 1820)
# ...

# %%
mydb.is_connected()
# Out:
# True

# %%
mydb.close()
